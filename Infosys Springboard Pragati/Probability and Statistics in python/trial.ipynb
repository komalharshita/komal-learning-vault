# %%
'''What is the probabilty of getting head if a coin is tossed?'''
total = 2
fav_outcomes = 1
probabilty = fav_outcomes / total
print("Probabilty: ", probabilty)
# Out:
# Probabilty:  0.5

# %%
emails = ["spam", "not spam", "spam", "spam", "not spam"]
total_email = len(emails)
fav_outcomes = emails.count("spam")
probab = fav_outcomes/ total_email
print("Probability: ", probab)
# Out:
# Probability:  0.6

# %%
'''Metaphrasing:Literal translation of world problems into mathematical
    models using sets, venn diagrams without loss of information '''
